# %%
import numpy as np
import pandas as pd
import pylab as plt

# %%
df_x = pd.read_excel('Biological_combined_model_result_data.xlsx')
df_x
# Out:
#                 Kb           Ki            Kc            Ks     y_pred  \
# 0     0.000000e+00     0.000000  0.000000e+00  3.180005e+00        NaN
# 1     1.294538e-09   154.797952  7.083705e-04  6.522983e-03  25.451723
# 2     7.213058e-08   507.632505  7.427140e-04  1.601113e-02  26.088061
# 3     1.976983e-08  4075.990191  9.448330e-03  4.958823e-03  26.772040
# 4     3.606368e-08  4588.293102  1.029744e-02  4.434846e-04  27.414072
# ...            ...          ...           ...           ...        ...
# 1191  7.857916e-09  2792.289868  4.287931e-03  4.911127e-09  26.268701
# 1192  1.422020e-08   446.976264  1.491230e-08  1.329768e-02  26.816858
# 1193  4.663071e-08  1851.137430  2.210251e-03  1.175143e-08  27.008640
# 1194  6.711176e-08  2582.197234  7.028028e-09  9.979077e-09  28.326227
# 1195  4.583062e-08  3642.378572  9.521667e-09  3.792831e-09  28.656280
#
#               y
# 0     25.343812
# 1     25.451826
# 2     26.189558
# 3     26.875160
# 4     27.472448
# ...

# %%
TMP = df_x.y
TMP_pred = df_x.y_pred

plt.figure(figsize=(12,10))
plt.plot(TMP, 'k')
plt.plot(TMP_pred, 'b')
plt.ylabel("TMP", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.xlabel("Time", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)
plt.legend(('TMP_measured', 'TMP_predicted'))
# plt.tight_layout()
# plt.savefig('EMD TMP MemD', dpi=120)
plt.show()
# Out:
# findfont: Font family ['Times new roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times new roman'] not found. Falling back to DejaVu Sans.

# %%
Kb = df_x.Kb
Ki = df_x.Ki
Kc = df_x.Kc
Ks = df_x.Ks

plt.figure(figsize=(12,10))
plt.subplot(5, 1, 1)
plt.plot(TMP, 'g')
plt.ylabel("TMP", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 2)
plt.plot(Kb, 'b')
plt.ylabel("Kb", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 3)
plt.plot(Ki, 'b')
plt.ylabel("Ki", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 4)
plt.plot(Kc, 'b')
plt.ylabel("Kc", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 5)
plt.plot(Ks, 'b')
plt.ylabel("Ks", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.xlabel("Time", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.show()

# %%
# Outlier removal
new_Kb = df_x.Kb
new_Kb = new_Kb[new_Kb > -2e-7]

new_Ki = df_x.Ki
new_Ki = new_Ki[new_Ki > -5000]

new_Kc = df_x.Kc
new_Kc = new_Kc[new_Kc > -0.05]

new_Ks = df_x.Ks
new_Ks = new_Ks[new_Ks < 0.05]

# Plotting
plt.figure(figsize=(12,10))
plt.subplot(5, 1, 1)
plt.plot(TMP, 'g')
plt.ylabel("TMP", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 2)
plt.plot(new_Kb, 'b')
plt.ylabel("Kb", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 3)
plt.plot(new_Ki, 'b')
plt.ylabel("Ki", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 4)
plt.plot(new_Kc, 'b')
plt.ylabel("Kc", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 5)
plt.plot(new_Ks, 'b')
plt.ylabel("Ks", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.xlabel("Time", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.show()

# %%
data = df_x[['Kb', 'Ki', 'Kc', 'Ks', 'y']]
data
# Out:
#                 Kb           Ki            Kc            Ks          y
# 0     0.000000e+00     0.000000  0.000000e+00  3.180005e+00  25.343812
# 1     1.294538e-09   154.797952  7.083705e-04  6.522983e-03  25.451826
# 2     7.213058e-08   507.632505  7.427140e-04  1.601113e-02  26.189558
# 3     1.976983e-08  4075.990191  9.448330e-03  4.958823e-03  26.875160
# 4     3.606368e-08  4588.293102  1.029744e-02  4.434846e-04  27.472448
# ...            ...          ...           ...           ...        ...
# 1191  7.857916e-09  2792.289868  4.287931e-03  4.911127e-09  26.739897
# 1192  1.422020e-08   446.976264  1.491230e-08  1.329768e-02  26.865142
# 1193  4.663071e-08  1851.137430  2.210251e-03  1.175143e-08  27.452191
# 1194  6.711176e-08  2582.197234  7.028028e-09  9.979077e-09  28.052543
# 1195  4.583062e-08  3642.378572  9.521667e-09  3.792831e-09  28.473508
#
# [1196 rows x 5 columns]

# %%
data = df_x[['Kb', 'Ki', 'Kc', 'Ks', 'y']]
data.rename(columns = {'y':'TMP'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
import seaborn as sns

cor = data.corr()

plt.figure(figsize=(12,10))
res = sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 18)
res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 18)

plt.show()

# %%
new_data = data
new_data.rename(columns = {'Kb':'New_Kb', 'Ki':'New_Ki', 'Kc':'New_Kc', 'Ks':'New_Ks'}, inplace=True)

new_data
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#             New_Kb       New_Ki        New_Kc        New_Ks        TMP
# 0     0.000000e+00     0.000000  0.000000e+00  3.180005e+00  25.343812
# 1     1.294538e-09   154.797952  7.083705e-04  6.522983e-03  25.451826
# 2     7.213058e-08   507.632505  7.427140e-04  1.601113e-02  26.189558
# 3     1.976983e-08  4075.990191  9.448330e-03  4.958823e-03  26.875160
# 4     3.606368e-08  4588.293102  1.029744e-02  4.434846e-04  27.472448
# ...            ...          ...           ...           ...        ...
# 1191  7.857916e-09  2792.289868  4.287931e-03  4.911127e-09  26.739897
# 1192  1.422020e-08   446.976264  1.491230e-08  1.329768e-02  26.865142
# ...

# %%
new_data.New_Kb = new_data.New_Kb[new_data.New_Kb > -2e-7]
new_data.New_Ki = new_data.New_Ki[new_data.New_Ki > -5000]
new_data.New_Kc = new_data.New_Kc[new_data.New_Kc > -0.05]
new_data.New_Ks = new_data.New_Ks[new_data.New_Ks < 0.05]
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   New_Kb  1193 non-null   float64
#  1   New_Ki  1195 non-null   float64
#  2   New_Kc  1194 non-null   float64
#  3   New_Ks  1150 non-null   float64
#  4   TMP     1196 non-null   float64
# dtypes: float64(5)
# memory usage: 46.8 KB
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
cor = new_data.corr()

plt.figure(figsize=(12,10))
res = sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 18)
res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 18)

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(new_data)

scaled_data = scaler.transform(new_data)
scaled_data = pd.DataFrame(scaled_data, columns=new_data.columns)
scaled_data
# Out:
#         New_Kb    New_Ki    New_Kc        New_Ks       TMP
# 0     0.371373  0.226403  0.380792           NaN  0.338003
# 1     0.374325  0.234476  0.386620  1.308849e-01  0.339975
# 2     0.535907  0.252877  0.386903  3.212662e-01  0.353450
# 3     0.416469  0.438972  0.458532  9.949970e-02  0.365973
# 4     0.453636  0.465689  0.465518  8.898601e-03  0.376883
# ...        ...       ...       ...           ...       ...
# 1191  0.389297  0.372025  0.416072  9.854268e-08  0.363503
# 1192  0.403810  0.249713  0.380792  2.668204e-01  0.365790
# 1193  0.477740  0.322942  0.398977  2.357947e-07  0.376513
# 1194  0.524459  0.361068  0.380792  2.002320e-07  0.387478
# 1195  0.475915  0.416358  0.380792  7.610387e-08  0.395167
#
# [1196 rows x 5 columns]

# %%
# Plotting
plt.figure(figsize=(12,10))
plt.subplot(5, 1, 1)
plt.plot(scaled_data.TMP, 'g')
plt.ylabel("TMP", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 2)
plt.plot(scaled_data.New_Kb, 'b')
plt.ylabel("Kb", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 3)
plt.plot(scaled_data.New_Ki, 'b')
plt.ylabel("Ki", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 4)
plt.plot(scaled_data.New_Kc, 'b')
plt.ylabel("Kc", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.subplot(5, 1, 5)
plt.plot(scaled_data.New_Ks, 'b')
plt.ylabel("Ks", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.yticks(fontsize=13, fontname = 'Times new roman')
plt.xticks(fontsize=13, fontname = 'Times new roman')
plt.xlim(0,1196)

plt.xlabel("Time", fontsize=16, weight = 'bold', fontname = 'Times new roman')
plt.show()

# %%
cor = scaled_data.corr()

plt.figure(figsize=(12,10))
res = sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
res.set_xticklabels(res.get_xmajorticklabels(), fontsize = 18)
res.set_yticklabels(res.get_ymajorticklabels(), fontsize = 18)

plt.show()

# %%
from sklearn.feature_selection import mutual_info_regression

scaled_data = scaled_data.fillna(0)

X = scaled_data[['New_Kb', 'New_Ki', 'New_Kc', 'New_Ks']]
y = scaled_data.TMP

discrete_features = X.dtypes == int

def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

mi_scores = make_mi_scores(X, y, discrete_features)
mi_scores[::1]  # show a few features with their MI scores
print(mi_scores)
# Out:
# New_Ki    0.212024
# New_Kb    0.191920
# New_Kc    0.123455
# New_Ks    0.111307
# Name: MI Scores, dtype: float64

# %%
# decision tree for feature importance on a regression problem
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from matplotlib import pyplot
# define dataset

DT_Reg = []
# define the model
model = DecisionTreeRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    DT_Reg.append(v)
# plot feature importance
pyplot.bar(X.columns, importance)
plt.title("DecisionTreeRegressor Feature importances via coefficients")
plt.show()

# %%
# random forest for feature importance on a regression problem
from sklearn.datasets import make_regression
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot


RF_Reg=[]
# define the model
model = RandomForestRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    RF_Reg.append(v)
# plot feature importance
pyplot.bar(X.columns, importance)
plt.title("RandomForestRegressor Feature importances via coefficients")
# Out:
# Text(0.5, 1.0, 'RandomForestRegressor Feature importances via coefficients')

# %%
# xgboost for feature importance on a regression problem
from sklearn.datasets import make_regression
from xgboost import XGBRegressor
from matplotlib import pyplot
# define the model

XGB_Reg=[]
model = XGBRegressor()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    XGB_Reg.append(v)
# plot feature importance
pyplot.bar(X.columns, importance)
plt.title("XGBRegressor Feature importances via coefficients")
# Out:
# [23:42:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Text(0.5, 1.0, 'XGBRegressor Feature importances via coefficients')

# %%
# permutation feature importance with knn for regression
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.inspection import permutation_importance
from matplotlib import pyplot

Premutation_Reg_KN=[]
# define the model
model = KNeighborsRegressor()
# fit the model
model.fit(X, y)
# perform permutation importance
results = permutation_importance(model, X, y, scoring='neg_mean_squared_error')
# get importance
importance = results.importances_mean
# summarize feature importance
for i,v in enumerate(importance):
    Premutation_Reg_KN.append(v)
# plot feature importance
pyplot.bar(X.columns, importance)
plt.title("Permutation Regression via coefficients")
# Out:
# Text(0.5, 1.0, 'Permutation Regression via coefficients')

# %%
Importance =pd.DataFrame()
Features =X.columns

columns=['DT_Reg', 'RF_Reg','XGB_Reg', 'Premutation_Reg_KN']
Importance["DT_Reg"]=DT_Reg
Importance["RF_Reg"]=RF_Reg
Importance["XGB_Reg"]=XGB_Reg
Importance["Premutation_Reg_KN"]=Premutation_Reg_KN
columns = Importance.columns
min_max_scaler = MinMaxScaler()
XX= Importance.values
XX = min_max_scaler.fit_transform(XX)


XX.shape
# Out:
# (4, 4)

# %%
#Heat map
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# defining index for the dataframe
idx = X.columns

# defining columns for the dataframe
cols = columns

# entering values in the index and columns  
# and converting them into a panda dataframe
df_1 = pd.DataFrame(XX,columns = cols, index = idx)



import matplotlib.pyplot as plt
import pandas as pd

# defining index for the dataframe
idx = X.columns

# defining columns for the dataframe
cols = columns

# entering values in the index and columns  
# and converting them into a panda dataframe
df_1 = pd.DataFrame(XX,columns = cols, index = idx)

import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()

df_1["Hybrid"] = df_1.sum(axis=1)/4
df_1 = df_1.sort_values(by='Hybrid', ascending=False)
# df_1.to_excel('Importance_TN.xls', sheet_name=Sheet)      


ANGLES = np.linspace(0.05, 2 * np.pi - 0.05, len(df_1), endpoint=False)
df_sorted= df_1
# Values for the x axis
ANGLES = np.linspace(0.05, 2 * np.pi - 0.05, len(df_sorted), endpoint=False)

# Cumulative length
LENGTHS = df_sorted["Hybrid"].values

# Mean gain length
DT_Reg = df_sorted["DT_Reg"].values
RF_Reg = df_sorted["RF_Reg"].values
XGB_Reg = df_sorted["XGB_Reg"].values
Premutation_Reg_KN = df_sorted["Premutation_Reg_KN"].values
Hybrid = df_sorted["Hybrid"].values

# Variables label
# Variables = df_sorted["Unnamed: 0"].values


GREY12 = "#1f1f1f"


# Set default font color to GREY12
plt.rcParams["text.color"] = GREY12

# The minus glyph is not available in Bell MT
# This disables it, and uses a hyphen
plt.rc("axes", unicode_minus=False)

# Colors
COLORS = ["#6C5B7B","#C06C84","#F67280","#F8B195"]

# Colormap
cmap = mpl.colors.LinearSegmentedColormap.from_list("my color", COLORS, N=256)

# Normalizer
norm = mpl.colors.Normalize(vmin=df_sorted.Hybrid.min(), vmax=df_sorted.Hybrid.max())

# Normalized colors. Each number of tracks is mapped to a color in the 
# color scale 'cmap'
COLORS = cmap(norm(df_sorted.Hybrid))


# Some layout stuff ----------------------------------------------
# Initialize layout in polar coordinates
fig, ax = plt.subplots(figsize=(9, 9), subplot_kw={"projection": "polar"})

# Set background color to white, both axis and figure.
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

ax.set_theta_offset(1.2 * np.pi / 2)
ax.set_ylim(-0.1, 1)

# Add geometries to the plot -------------------------------------
# See the zorder to manipulate which geometries are on top

# Add bars to represent the cumulative track lengths
ax.bar(ANGLES, LENGTHS, color=COLORS, alpha=0.5, width=1.52, zorder=10)

# Add dashed vertical lines. These are just references
ax.vlines(ANGLES, 0, 1, color=GREY12, ls=(0, (4, 4)), zorder=11)

# Add dots to represent the mean gain
#ax.scatter(ANGLES, Lasso, s=60, marker='^', color=GREY12, zorder=20)
ax.scatter(ANGLES, DT_Reg, s=60, marker="s",color='green', zorder=20)
ax.scatter(ANGLES, RF_Reg, s=60, marker="X",color='red', zorder=20)
ax.scatter(ANGLES, XGB_Reg, s=60, marker="*",color='blue', zorder=20)
ax.scatter(ANGLES, Premutation_Reg_KN, marker="o",s=60, color='yellow', zorder=20)
ax.scatter(ANGLES, Hybrid, marker="1", s=60, color='orange', zorder=20)

# Remove lines for polar axis (x)
ax.xaxis.grid(False)

# Remove spines
ax.spines["start"].set_color("none")
ax.spines["polar"].set_color("none")


XTICKS = ax.xaxis.get_major_ticks()
for tick in XTICKS:
    tick.set_pad(10)

Variables = ["Ki","Kc","Kb","Ks"]

# Set the labels
ax.set_xticks(ANGLES)
ax.set_xticklabels(Variables, size=20);

# fig.savefig('Importance_radar_'+Var+'-'+Sheet, dpi=500)
# Sheetname.append(Var+'-'+Sheet)
